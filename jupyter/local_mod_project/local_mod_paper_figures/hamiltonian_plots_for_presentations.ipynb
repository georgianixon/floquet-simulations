# %%
from floquet_simulations.periodic_functions import Cosine
from floquet_simulations.hamiltonians import CreateHFGeneral
from floquet_simulations.plot_functions import *
from numpy import pi
from pathlib import Path
from floquet_simulations.generate_gradients import ComputeAValsFromRequiredGradients, GetAValsFromBesselXVals
figsize_hams=(12,12)

PlotParams(fontsize=18)
import numpy as np

# %% [markdown]
# #### SSH4

# %%
#SSH4
num_sites = 17
centres = np.array(range(num_sites))
funcs = [Cosine]*num_sites
a1 = 16.917322691940058; a2 = -50; a3 = 38.315948852085626; a4 = -10
omega0 = 25; T = 2*pi/omega0
phi1 = 0; phi2 = 0; phi3 = 0; phi4 = 0
onsite1 =0.0697854749060796; onsite2 = 0.068;  onsite3=0;onsite4 = -0.068
# params = [onsite0, [a1, omega1, phi1, onsite1], [(a2, a3), (omega2, omega3), (phi2, phi3), onsite2], [a4, omega4, phi4, onsite4]]*2
params = ([ [a1, omega0, phi1, onsite1], [a2, omega0, phi2, onsite2], [a3, omega0, phi3, onsite3], [a4, omega0, phi4, onsite4]]*5)[:num_sites]
_, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)

colourbar_min = np.min(np.real(HF))
colourbar_max = np.max(np.real(HF))

plt.rc('text.latex', preamble=r'\usepackage{amsmath,nicefrac,xfrac}')
# mpl.verbose.level = 'debug-annoying'
 

print(colourbar_max, colourbar_min)
ssh_plot_dir_path = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"ssh4_model.png"
# PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad = 0.05, colourbar_size_percentage=10, save_location=ssh_plot_dir_path, axes_tick_pos=[0,2,4,6,8], axes_tick_labels=[1,3,5,7,9])
# PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad=0.05, colourbar_size_percentage=10, 
#                     save_location = False, axes_tick_pos=[0,2,4,6,8], axes_tick_labels=[1,3,5,7,9], 
#                     cmap_lims=(-0.8,0.4), colourbar_ticks = [-0.8,-0.6,-0.4,-0.2,0,0.2,0.4, 0.6])

PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad=0.1, colourbar_size_percentage=5, 
                    save_location = ssh_plot_dir_path,
                      axes_tick_pos=[int(i) for i in np.linspace(0,16,9)], axes_tick_labels=[int(i) for i in np.linspace(1,17,9)], 
                    data_cmap_lims = (-0.8, 0.8), colourbar_cmap_lims=(-0.8,0.4), colourbar_ticks = np.arange(-0.8,1.2,0.4), 
                    title_labelpad=15)
# Out:
# 0.3857062 -0.7295157

# %% [markdown]
# ### Twisted Phase

# %%
# num_sites = 9
# omega = 8; T = 2*pi/omega
# centres = np.array(range(num_sites))
# onsite = 0
# for t0 in [0,pi/4, pi/2, 3*pi/4]:
#     _, HF = CreateHFGeneral(num_sites,
#                             centres,
#                             [Cosine]*num_sites,
#                             [[10,omega,i*pi/8,onsite] for i in range(1,num_sites+1)],
#                             T,
#                             circle_boundary=0,
#                             t0=t0
#                             )



#     # colourbar_min = np.min(np.imag(HF))
#     # colourbar_max = np.max(np.imag(HF))

#     twisted_phase_plot_dir_path = Path().absolute().parent/"figures"/"cpgm_pres"/f"twisted_phase_model_t0={t0:.2f}.png"

#     # print(colourbar_max, colourbar_min)
#     # PlotImagHamiltonian(HF, figsize=figsize_hams, colourbar_pad = 0.05, colourbar_size_percentage=10, save_location=twisted_phase_plot_dir_path, axes_tick_pos=[0,2,4,6,8], axes_tick_labels=[1,3,5,7,9])
#     colourbar_tick_spacing=0.5
#     PlotImagHamiltonian(HF, figsize=figsize_hams, colourbar_pad=0.05, colourbar_size_percentage=10, 
#                         save_location = twisted_phase_plot_dir_path,
#                         axes_tick_pos=[0,2,4,6,8], axes_tick_labels=[1,3,5,7,9],
#                         data_cmap_lims = (-0.6,0.6), 
#                         colourbar_cmap_lims=(-0.5,0.5), colourbar_ticks = np.arange(-1,1+colourbar_tick_spacing,colourbar_tick_spacing))
#     print([np.imag(HF[i,i+1]) - np.imag(HF[i+1,i+2]) for i in range(7)])
np.linspace(0,8,5)
# Out:
# array([0., 2., 4., 6., 8.])

# %% [markdown]
# #### SSH

# %%
#SSH

num_sites = 17
centres = np.array(range(num_sites))
funcs = [Cosine]*num_sites
a1 = 39; a2 = 38; a3=-a1; a4=-a2
omega0 = 25; T = 2*pi/omega0
phi1 = 0; phi2 = 0; phi3 = 0; phi4 = 0
onsite1 =0; onsite2 = 0;  onsite3=0;onsite4 = 0
# params = [onsite0, [a1, omega1, phi1, onsite1], [(a2, a3), (omega2, omega3), (phi2, phi3), onsite2], [a4, omega4, phi4, onsite4]]*2
params = ([ [a1, omega0, phi1, onsite1], [a2, omega0, phi2, onsite2], [a3, omega0, phi3, onsite3], [a4, omega0, phi4, onsite4]]*5)[:num_sites]
_, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)

colourbar_min = np.min(np.real(HF))
colourbar_max = np.max(np.real(HF))

ssh_plot_dir_path = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"ssh_model.png"

import numpy as np
from floquet_simulations.plot_functions import *
                    
colourbar_min = np.min(np.real(HF))
colourbar_max = np.max(np.real(HF))
print(colourbar_min, colourbar_max)

PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad=0.1, colourbar_size_percentage=5, 
                    save_location = ssh_plot_dir_path,  axes_tick_pos=[int(i) for i in np.linspace(0,16,9)], axes_tick_labels=[int(i) for i in np.linspace(1,17,9)],
                    colourbar_cmap_lims=(-1,0.5), colourbar_ticks = np.arange(-1,1+.5,0.5),
                    title_labelpad=15)
ssh_plot_dir_path.as_posix().find("pdf")
# Out:
# -0.9986129 0.2865181
# -1

# %% [markdown]
# #### Edge State

# %%
from floquet_simulations.hamiltonians import GetEvalsAndEvecsGen

figsize_evec = (12,6)
evals, evecs = GetEvalsAndEvecsGen(HF)

cm_unit = 1/2.54
fig, ax = plt.subplots(figsize=(figsize_evec[0]*cm_unit, figsize_evec[1]*cm_unit))
ax.plot(np.linspace(1,num_sites,num_sites), np.real(evecs[:,8]), 
            linestyle = "-",
                # linestyle=(1,(3,1,1,1,1)), 
                c='#006F63')
ax.set_ylabel("probability\ndistribution", rotation = 90, labelpad = 3)
ax.set_xlabel(r"site")
ax.set_xticks([int(i) for i in np.linspace(1,17,9)])
fig.savefig(Path().absolute().parent.parent/"figures"/"cpgm_pres"/"zero_energy_edge_state_ssh.png", format="png", bbox_inches="tight")
plt.show()

# %%
#SSH3
num_sites = 17
centres = np.array(range(num_sites))
funcs = [Cosine]*num_sites
a1 = -40; a2 = 2.5; a3=-52; a4=-a1; a5=-a2; a6=-a3
omega0 = 25; T = 2*pi/omega0
phi0 = 0
onsite0 =0
params = ([[a_val, omega0, phi0, onsite0] for a_val in [a1, a2, a3, a4, a5, a6]]*3)[:num_sites]
_, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)
 
                     
colourbar_min = np.min(np.real(HF))
colourbar_max = np.max(np.real(HF))
print(colourbar_min, colourbar_max)


ssh_plot_dir_path = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"ssh3_model.png"

PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad = 0.1, colourbar_size_percentage=5, save_location=ssh_plot_dir_path,
                    axes_tick_pos=[int(i) for i in np.linspace(0,16,9)], axes_tick_labels=[int(i) for i in np.linspace(1,17,9)],
                    data_cmap_lims = (-0.5,0.5), colourbar_cmap_lims=(-0.4,0.4), colourbar_ticks = np.arange(-1,1,0.2),
                    title_labelpad=15)
# Out:
# -0.3943039 0.3982707

# %%
#bessel
num_sites = 5
centres = [2]
funcs = [Cosine]
a0 = 40
phi0 = 0
onsite0 =0
num_omegas = 200
hoppings = np.empty(num_omegas, dtype=np.complex128)

omega0s = np.linspace(4,40,num_omegas)
for i, omega0 in enumerate(omega0s):
    T = 2*pi/omega0
    params = [[a0, omega0, phi0, onsite0]]
    _, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)
    hoppings[i] = HF[2,3]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 15
#      13 T = 2*pi/omega0
#      14 params = [[a0, omega0, phi0, onsite0]]
# ---> 15 _, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)
#      16 hoppings[i] = HF[2,3]
#
# File ~/floquet-simulations/src/floquet_simulations/hamiltonians.py:585, in CreateHFGeneral(num_sites, centre, func, params, T, circle_boundary, t0, hermitian_accuracy_dp)
#     583 for A_site_start in range(num_sites):
#     584     psi0 = np.zeros(num_sites, dtype=np.complex_); psi0[A_site_start] = 1
# --> 585     sol = SolveSchrodingerGeneral(num_sites, centre, func, params, tspan, n_timesteps, psi0, circle_boundary=circle_boundary)
#     586     UT[:,A_site_start]=sol[:,-1]
#     588 # evals_U, evecs = eig(UT)
#
# ...

# %%
from scipy.special import jv
cm_unit = 1/2.54
plt.rc('text.latex', preamble=r'\usepackage{amsmath,nicefrac,xfrac}')
figsize_rec = (12,12/1.5)
fig, ax = plt.subplots(figsize=(figsize_rec[0]*cm_unit, figsize_rec[1]*cm_unit))
ax.plot(1/omega0s, -np.real(hoppings), color='#006F63')
ax.plot(1/omega0s, jv(0, 40/omega0s), ':', color="#C30934", label=r"$\mathcal{J}_0(40/\omega)$")
ax.set_xlabel(r"$\nicefrac{1}{\omega}$", fontsize=14, labelpad=0.1)
ax.set_ylabel(r"$J'$", fontsize=14)#
# plt.legend()
bessel_plot_dir =  Path().absolute().parent.parent/"figures"/"cpgm_pres"/"bessel_func_b.png"
fig.savefig(bessel_plot_dir, format="png", bbox_inches="tight")
plt.show()

# %%
#single site

num_sites = 13
centres = [6]
funcs = [Cosine]
a0 = 90
omega0 = 25; T = 2*pi/omega0
phi0 = 0
onsite0 =0
params = [[a0, omega0, phi0, onsite0]]
_, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)
 
                     
colourbar_min = np.min(np.real(HF))
colourbar_max = np.max(np.real(HF))
print(colourbar_min, colourbar_max)


ssh_plot_dir_path = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"single_site_shake.png"



PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad = 0.05, colourbar_size_percentage=10, save_location=ssh_plot_dir_path,
                     axes_tick_pos=[int(i) for i in np.linspace(0,12,7)], axes_tick_labels=[int(i) for i in np.linspace(1,13,7)],
                    data_cmap_lims = (-1,1), colourbar_cmap_lims=(-1,1), colourbar_ticks = np.arange(-1,1.5,0.5), title_labelpad=15)
# Out:
# -1.0 0.3917377

# %%
figsize=figsize_hams; colourbar_pad=0.05; colourbar_size_percentage=10
axes_tick_pos=[int(i) for i in np.linspace(0,12,7)]; axes_tick_labels=[int(i) for i in np.linspace(1,13,7)]
data_cmap_lims = (-1,1)
colourbar_cmap_lims=(-1,1);  colourbar_ticks = np.arange(-1,1.2,0.2)
"""
cmap_lims is tuple giving range between -1 and 1, ie proportion of full colour map that is used. 
""" 

linthresh = 1e-1
norm=mpl.colors.SymLogNorm(linthresh=linthresh, linscale=1, vmin=-1.0, vmax=1.0, base=10)

# 
# 
cmap = LinearSegmentedColormap.from_list('custom hamiltonians', ['#006F63', "#FFFFFF", '#F78320'], N=256)

cm_unit = 1/2.54

fig, ax = plt.subplots(constrained_layout=True, 
                        figsize=(figsize[0]*cm_unit, figsize[1]*cm_unit))
ax.matshow(np.real(HF), interpolation='none', cmap=cmap,  norm=norm)
ax.set_title( r'$\mathrm{Real}\left\{ {H_{S}^{t_0}}_{n,m} \right\}$', pad=15)
ax.tick_params(axis="x", bottom=True, top=False, labelbottom=True, 
    labeltop=False)  
ax.set_xlabel('m')
ax.set_ylabel('n', rotation=0, labelpad=10)
if axes_tick_pos:
    ax.set_xticks(axes_tick_pos)
    ax.set_yticks(axes_tick_pos)
if axes_tick_labels:
    ax.set_xticklabels(axes_tick_labels)
    ax.set_yticklabels(axes_tick_labels)

divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size=f"{colourbar_size_percentage}%", pad=colourbar_pad)

# if colourbar_cmap_lims:
#     new_norm = mpl.colors.Normalize(vmin=colourbar_cmap_lims[0], vmax=colourbar_cmap_lims[1])
#     new_cmap = truncate_colormap(cmap, (colourbar_cmap_lims[0]-data_cmap_lims[0])/(data_cmap_lims[1] - data_cmap_lims[0]), (colourbar_cmap_lims[1]-data_cmap_lims[0])/(data_cmap_lims[1] - data_cmap_lims[0]))
#     fig.colorbar(mpl.cm.ScalarMappable(norm=new_norm, cmap=new_cmap), cax=cax, ticks = colourbar_ticks)
# else:
fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap), cax=cax )
save_location = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"single_site_shake_log.png"
fig.savefig(save_location, format="png", bbox_inches="tight", dpi=508)
plt.show()

# %%
from scipy.special import jv
Ndiffs = 24
ymin = jv(0, 3.8316)
drive_style = "alternating"
omega = 25
# xzero = 2.4048
gradients = np.linspace(-ymin, ymin, Ndiffs) # for linear


# print(gradients)
# print("change in tunnelling", f"{gradients[1]-gradients[0]:.4f}")
# gradients = np.array([ymin, -ymin]*(int(Ndiffs/2)))  # for SSH
# gradients = np.array([0.4, -0.1, 0.1]*4) #for SSH3
# gradients = np.array([0.9, 0.4]*int(Ndiffs/2)) # for SSH not negative, makes A's lower
xvals = ComputeAValsFromRequiredGradients(gradients)

A_vals = GetAValsFromBesselXVals(xvals, omega, addition_type=drive_style, constant_shift="zero centre") # get actual shaking values


#oscilating A_vals
# A_vals = np.array([i%2 for i in range(Ndiffs +1)])*10


_, HF = CreateHFGeneral(Ndiffs+1,
                        [int(i) for i in list(np.linspace(0,Ndiffs,Ndiffs+1))],
                        [Cosine]*(Ndiffs+1),
                        [[i,omega,0,0] for i in A_vals], #a, omega, phi onsite
                        2*pi/omega,
                        0
                        )

#make real
if np.all(np.imag(HF))==0:
    HF =np.real(HF)
black_hole_plot_dir_path = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"black_hole_ham.png"
PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad = 0.1, colourbar_size_percentage=5, save_location=black_hole_plot_dir_path,
                     axes_tick_pos=[int(i) for i in np.linspace(0,24,13)], axes_tick_labels=[int(i) for i in np.linspace(1,25,13)],
                    data_cmap_lims = (-0.5,0.5), colourbar_cmap_lims=(-0.5,0.5), colourbar_ticks = np.arange(-1,1.5,0.5), title_labelpad=15)
print(jv(0, 3.8316))

#make real
if np.all(np.imag(HF))==0:
    HF =np.real(HF)
# Out:
# -0.40275939344110157

# %%
fig, ax = plt.subplots(figsize=(12/2.56, 7/2.56))
ax.plot(A_vals, '.', c='#006F63')
ax.set_ylabel(r"$A$", rotation=0)
ax.set_xlabel(r"$i$")
save_location = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"black_hole_a_vals.png"
fig.savefig(save_location, format="png", bbox_inches="tight", dpi=508)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12/2.56, 7/2.56))
ax.plot(np.diag(HF, k=1), '.', c='#006F63')
ax.set_ylabel(r"$J_{i,i+1}$", rotation=0, labelpad=10)
ax.set_xlabel(r"$i$")
save_location = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"black_hole_tunnelling.png"
fig.savefig(save_location, format="png", bbox_inches="tight", dpi=508)
plt.show()

# %%
#SSH3
num_sites = 17
centres = np.array(range(num_sites))
funcs = [Cosine]*num_sites
a1 = -40; a2 = 2.5; a3=-52; a4=-a1; a5=-a2; a6=-a3
omega0 = 25; T = 2*pi/omega0
phi0 = 0
onsite0 =0
params = ([[a_val, omega0, phi0, onsite0] for a_val in [a1, a2, a3, a4, a5, a6]]*3)[:num_sites]
_, HF = CreateHFGeneral(num_sites, centres, funcs, params, T, circle_boundary=0)
 
                     
colourbar_min = np.min(np.real(HF))
colourbar_max = np.max(np.real(HF))
print(colourbar_min, colourbar_max)


ssh_plot_dir_path = Path().absolute().parent.parent/"figures"/"cpgm_pres"/"ssh3_model.png"

PlotRealHamiltonian(HF, figsize=figsize_hams, colourbar_pad = 0.1, colourbar_size_percentage=5, save_location=ssh_plot_dir_path,
                    axes_tick_pos=[int(i) for i in np.linspace(0,16,9)], axes_tick_labels=[int(i) for i in np.linspace(1,17,9)],
                    data_cmap_lims = (-0.5,0.5), colourbar_cmap_lims=(-0.4,0.4), colourbar_ticks = np.arange(-1,1,0.2),
                    title_labelpad=15)
# Out:
# -0.3943039 0.3982707
