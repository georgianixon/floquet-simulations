# %%
import pandas as pd
from pathlib import Path
read_dir = Path().absolute().parent.parent/"data"/"black_hole"/"asmae_data"
import numpy as np
import matplotlib.pyplot as plt
from floquet_simulations.plot_functions import PlotParams
fontsize=9
PlotParams(fontsize=9)
save_dir = Path().absolute().parent.parent/"figures"/"thesis"/"black_hole"
figsize = (4.4, 4.4)
cm_unit = 1/2.54
save_fig_dir = Path().absolute().parent.parent/"figures"/"thesis"/"black_hole"
#for b
n_b = 6
energies0 = pd.read_csv(read_dir/'energies_a_new_0.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
energies1 = pd.read_csv(read_dir/'energies_a_new_1.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
energies2 = pd.read_csv(read_dir/'energies_a_new_2.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
energies3 = pd.read_csv(read_dir/'energies_a_new_3.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
ps0 = pd.read_csv(read_dir/'ps_a_new_0.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
ps1 = pd.read_csv(read_dir/'ps_a_new_1.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
ps2 = pd.read_csv(read_dir/'ps_a_new_2.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]
ps3 = pd.read_csv(read_dir/'ps_a_new_3.txt', sep=" ", header=None).to_numpy().flatten()[:n_b]

# for c
time_data0 = pd.read_csv(read_dir/'fig3_c_time_data_a=1.0.txt', sep=" ", header=None).to_numpy().flatten()
time_data1 = pd.read_csv(read_dir/'fig3_c_time_data_a=1.6666666666666665.txt', sep=" ", header=None).to_numpy().flatten()
time_data2 = pd.read_csv(read_dir/'fig3_c_time_data_a=2.333333333333333.txt', sep=" ", header=None).to_numpy().flatten()
time_data3 = pd.read_csv(read_dir/'fig3_c_time_data_a=3.0.txt', sep=" ", header=None).to_numpy().flatten()

pop_data0 = pd.read_csv(read_dir/'fig3_c_population_data_a=1.0.txt', sep=" ", header=None).to_numpy().flatten()
pop_data1 = pd.read_csv(read_dir/'fig3_c_population_data_a=1.6666666666666665.txt', sep=" ", header=None).to_numpy().flatten()
pop_data2 = pd.read_csv(read_dir/'fig3_c_population_data_a=2.333333333333333.txt', sep=" ", header=None).to_numpy().flatten()
pop_data3 = pd.read_csv(read_dir/'fig3_c_population_data_a=3.0.txt', sep=" ", header=None).to_numpy().flatten()

#for d
temp0 = pd.read_csv(read_dir/'fig3_d_temps_a=1.0.txt', sep=" ", header=None).to_numpy().flatten() 
temp1 = pd.read_csv(read_dir/'fig3_d_temps_a=1.6666666666666665.txt', sep=" ", header=None).to_numpy().flatten() 
temp2 = pd.read_csv(read_dir/'fig3_d_temps_a=2.333333333333333.txt', sep=" ", header=None).to_numpy().flatten() 
temp3 = pd.read_csv(read_dir/'fig3_d_temps_a=3.0.txt', sep=" ", header=None).to_numpy().flatten()
tfin0 = pd.read_csv(read_dir/'fig3_d_tfin_a=1.0.txt', sep=" ", header=None).to_numpy().flatten()
tfin1 = pd.read_csv(read_dir/'fig3_d_tfin_a=1.6666666666666665.txt', sep=" ", header=None).to_numpy().flatten()
tfin2 = pd.read_csv(read_dir/'fig3_d_tfin_a=2.333333333333333.txt', sep=" ", header=None).to_numpy().flatten()
tfin3 = pd.read_csv(read_dir/'fig3_d_tfin_a=3.0.txt', sep=" ", header=None).to_numpy().flatten()

TH0 = 1/4/np.pi
TH1 = 5/3/4/np.pi
TH2 = 7/3/4/np.pi
TH3 = 3/4/np.pi

colour0 = "#0f1980"#"#1565C0"
colour1 = "#006F63"
colour2 = "#F78320"
colour3 = "#A91401"
marker0 = "*"
marker1 =  "+"
marker2 = "o"
marker3 = "x"
markersize = 4
markersize_p1 = 2

# %%
m0, b0 = np.polyfit(energies0[1:], np.log(ps0[1:]), 1)
m1, b1 = np.polyfit(energies1[1:], np.log(ps1[1:]), 1)
m2, b2 = np.polyfit(energies2[1:], np.log(ps2[1:]), 1)
m3, b3 = np.polyfit(energies3[1:], np.log(ps3[1:]), 1)
linewidth = 0.5
fig, ax = plt.subplots(figsize = (figsize[0]*cm_unit, figsize[1]*cm_unit))
ax.tick_params(axis="x", bottom=True, top=False, labelbottom=True, 
        labeltop=False, direction = "in", length = 3, pad=1)  
ax.tick_params(axis="y", left=True, right=False, labelleft=True, 
        labelright=False, direction = "in", length = 3, pad=1)  
ax.semilogy( energies0, ps0, 'o', markersize=markersize_p1, color=colour0)
ax.semilogy( energies1, ps1, 'o', markersize=markersize_p1, color=colour1)
ax.semilogy( energies2, ps2, 'o', markersize=markersize_p1, color=colour2)
ax.semilogy( energies3, ps3, 'o', markersize=markersize_p1, color=colour3)
ax.plot(energies0, np.exp(m0*energies0 + b0), color=colour0, linestyle='-', linewidth=linewidth, label=rf"$\tilde{{T}}_H = {-1/m0:.3f}$")
ax.plot(energies1, np.exp(m1*energies1 + b1), color=colour1, linestyle='-', linewidth=linewidth,label=rf"$\tilde{{T}}_H = {-1/m1:.3f}$")
ax.plot(energies2, np.exp(m2*energies2 + b2), color=colour2, linestyle='-', linewidth=linewidth,label=rf"$\tilde{{T}}_H = {-1/m2:.3f}$")
ax.plot(energies3, np.exp(m3*energies3 + b3), color=colour3, linestyle='-', linewidth=linewidth,label=rf"$\tilde{{T}}_H = {-1/m3:.3f}$")
ax.set_xlim([0,5.4])
ax.set_xticks([0,1,2,3,4,5])
ax.set_ylabel(r"$P_n$", rotation=0)
ax.set_xlabel(r"$E_n$")
plt.legend(fontsize=6, bbox_to_anchor=(0,0.03,1,1))
ax.yaxis.set_label_coords(-0.12,0.92)
ax.xaxis.set_label_coords(0.5,-0.08)
fig.savefig(save_fig_dir/"probabilities.pdf", format="pdf", bbox_inches="tight", pad_inches=0.03)
fig.savefig(save_fig_dir/"probabilities.png", format="png", bbox_inches="tight", pad_inches=0.03,dpi=600)

plt.show()

# %%
print(TH0, TH1, TH2, TH3)
# Out:
# 0.07957747154594767 0.13262911924324614 0.18568076694054458 0.238732414637843

# %%
fig, ax = plt.subplots(figsize = ((figsize[0])*cm_unit, figsize[1]*cm_unit))
tf_n = 11
ax.vlines([time_data0[tf_n],time_data1[tf_n],time_data2[tf_n],time_data3[tf_n]], colors=[colour0, colour1, colour2, colour3],ymin=0, ymax=0.1,linestyle="--", linewidth =linewidth)
ax.plot(time_data0, pop_data0,'*--', markersize=markersize_p1+1, color=colour0, linewidth=linewidth, label=rf"$T_H = {TH0:.2f}$")
ax.plot(time_data1, pop_data1,'x--', markersize=markersize_p1+1, color=colour1, linewidth=linewidth, label=rf"$T_H = {TH1:.2f}$")
ax.plot(time_data2, pop_data2,'+--', markersize=markersize_p1+2, color=colour2, linewidth=linewidth, label=rf"$T_H = {TH2:.2f}$")
ax.plot(time_data3, pop_data3,'o--', markersize=markersize_p1, color=colour3, linewidth=linewidth, label=rf"$T_H = {TH3:.2f}$")
# ax.legend(fontsize=7, bbox_to_anchor=(0.1,0.06,1,1))
ax2 = fig.add_axes([0.65, 0.45, 0.2, 0.38])
ax2.plot(time_data0, pop_data0, 'o--', markersize=markersize_p1, color=colour0, linewidth=linewidth)
ax2.plot(time_data1*5/3, pop_data1, 'o--', markersize=markersize_p1, color=colour1, linewidth=linewidth)
ax2.plot(time_data2*7/3, pop_data2, 'o--', markersize=markersize_p1, color=colour2, linewidth=linewidth)
ax2.plot(time_data3*3, pop_data3, 'o--', markersize=markersize_p1, color=colour3, linewidth=linewidth)
ax2.set_xticks([0,8])
ax2.set_yticks([0,0.1])
ax2.set_yticklabels([r"$0$", r"$.1$"])

ax2.tick_params(axis="x", bottom=True, top=False, labelbottom=True, 
        labeltop=False, direction = "in", length = 3, pad=1, labelsize=7)  
ax2.tick_params(axis="y", left=True, right=False, labelleft=True, 
        labelright=False, direction = "in", length = 3, pad=1, labelsize=7)  

ax.tick_params(axis="x", bottom=True, top=False, labelbottom=True, 
        labeltop=False, direction = "in", length = 3, pad=1)  
ax.tick_params(axis="y", left=True, right=False, labelleft=True, 
        labelright=False, direction = "in", length = 3, pad=1)  
ax.set_xlabel(r"$t$")
ax.set_ylabel(r"$\langle \hat{n}_h(t) \rangle$")
ax.set_yticks([0,0.05, 0.1])
ax.set_ylim([0,0.1])
ax.set_xlim([0,8.2])
ax.set_yticklabels([r"$0$", r"$.05$", r"$.1$"])
ax.set_xticks([0,4,8])
ax.yaxis.set_label_coords(-0.03,0.78)
ax.xaxis.set_label_coords(0.5,-0.08)
ax.set_xticks([time_data0[tf_n], time_data1[tf_n], time_data2[tf_n], time_data3[tf_n]], minor=True)
ax.set_xticklabels([r"$t_f$",r"$t_f$",r"$t_f$",r"$t_f$"],minor=True, fontsize=7)
ax.get_xticklabels(minor=True)[0].set_color(colour0)
ax.get_xticklabels(minor=True)[1].set_color(colour1)
ax.get_xticklabels(minor=True)[2].set_color(colour2)
ax.get_xticklabels(minor=True)[3].set_color(colour3)
# fig.savefig(save_fig_dir/"walks.pdf", format="pdf", bbox_inches="tight", pad_inches=0)
fig.savefig(save_fig_dir/"walks.png", format="png", bbox_inches="tight", pad_inches=0.03,dpi=600)


plt.show()

# %%
m0, b0 = np.polyfit(np.log(tfin0), np.log(temp0), 1)
cont_tfin = np.linspace(tfin0[0], tfin0[-1], 100)
fig, ax = plt.subplots(figsize = (figsize[0]*cm_unit, figsize[1]*cm_unit))
ax.tick_params(axis="x", bottom=True, top=False, labelbottom=True, 
        labeltop=False, direction = "in", length = 3, pad=1)  
ax.tick_params(axis="y", left=True, right=False, labelleft=True, 
        labelright=False, direction = "in", length = 3, pad=1)  
ax.plot(tfin0[0], temp0[0], "*", markersize=markersize_p1+1, color=colour0)
ax.plot(tfin0[1], temp0[1], "x", markersize=markersize_p1+1, color=colour1)
ax.plot(tfin0[2], temp0[2], "+", markersize=markersize_p1+2, color=colour2)
ax.plot(tfin0[3], temp0[3], "o", markersize=markersize_p1, color=colour3)
ax.plot(cont_tfin, np.exp(m0*np.log(cont_tfin) + b0), color="0.5", linewidth=linewidth, label=rf"$T_H = {np.exp(b0)*4*np.pi:.2f}/(4 \pi t_f)$")
ax.set_xticks([1.5,3,4.5])
ax.set_xticklabels([r"$1.5$",r"$3$",r"$4.5$"])
ax.set_xlabel(r"$t_f$")
ax.set_ylabel(r"$T_H$")
ax.set_ylim([0.06, 0.25])
ax.yaxis.set_label_coords(-0.08,0.86)
ax.xaxis.set_label_coords(0.5,-0.08)
ax.set_xlim([1.4, 4.8])
ax.legend(fontsize=7, bbox_to_anchor=(0.04,0.04,1,1))

# ax2 = fig.add_axes([0.5, 0.5, 0.35, 0.35])
ax2 = ax.inset_axes([0.5, 0.4, 0.43, 0.43], transform=ax.transAxes)
ax2.loglog(cont_tfin, np.exp(m0*np.log(cont_tfin) + b0), color="0.5", linewidth=linewidth)
ax2.loglog(tfin0[0], temp0[0], "*", markersize=markersize_p1+1, color=colour0)
ax2.loglog(tfin0[1], temp0[1], "x", markersize=markersize_p1+1, color=colour1)
ax2.loglog(tfin0[2], temp0[2], "+", markersize=markersize_p1+2, color=colour2)
ax2.loglog(tfin0[3], temp0[3], "o", markersize=markersize_p1, color=colour3)
ax2.tick_params(axis="x", bottom=True, top=False, labelbottom=True, 
        labeltop=False, direction = "in", length = 3, pad=1)  
ax2.tick_params(axis="y", left=True, right=False, labelleft=True, 
        labelright=False, direction = "in", length = 3, pad=1) 
ax2.set_xticks([1.5, 4.5],minor=True)
ax2.set_yticks([],minor=True)
ax2.set_yticks([0.1,0.25],minor=False)
ax2.set_xticklabels([r"$1.5$", r"$4.5$"],minor=True,fontsize=7)
ax2.set_yticklabels([r"$0.1$", r"$0.25$"],minor=False, fontsize=7)

# ax2.loglog(tfin0, 4.6/4/np.pi/tfin0, "x--")
fig.savefig(save_fig_dir/"measured_tfs.pdf", format="pdf", bbox_inches="tight", pad_inches=0)
plt.show()

# %%
np.exp(np.log(3))
# Out:
# 3.0000000000000004

# %%
##############
##############

# fig (d) : population peak plot with log-log inset 
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
L = 100
a_list = np.linspace(1, 3, 4)
temps = a_list /(4*np.pi)
time = np.linspace(0, 30, 20) 
markers = ['.', '*', '+', 'x'] 
color = cm.rainbow(np.linspace(0.1, 1, len(a_list)))

fig, ax1 = plt.subplots()

tfin = [np.linspace(0, 30*a_list[0]/a, 30)[18] for a in a_list]

temps2 = np.linspace(temps[0], temps[-1], 100) 

gamma = 2*0.093*L
tfits = [gamma/(4*np.pi*t) for t in temps2]

ax2 = fig.add_axes([0.54, 0.4, 0.2, 0.37])

ax2.plot(np.log(tfits), np.log(temps2), 'k-', linewidth=1.8)

ax1.plot(tfits, temps2, 'k-', linewidth=1.8, label=fr'$\tilde T_H = \gamma /(4\pi t_f)$, $\gamma = {gamma}$')

for i_a in range(len(a_list)):
    
    ax1.plot(tfin[i_a], temps[i_a], marker=markers[i_a], c=color[i_a], markersize=10, mew=2, label='$T_H$')
    ax2.plot(np.log(tfin[i_a]), np.log(temps[i_a]), marker=markers[i_a], c=color[i_a], markersize=10, mew=2, label='$T_H$')

# handles, labels = plt.gca().get_legend_handles_labels()
handles, labels = ax1.get_legend_handles_labels()

# order = [0]
i = 0
ax1.legend([handles[i]], [labels[i]], fontsize = 12)
# ax1.legend([handles[idx] for idx in order], [labels[idx] for idx in order], fontsize = 12)

ax1.set_xlabel('$t_f$', fontsize = 20)
ax1.set_ylabel(r'$\tilde T_H$', fontsize = 20)

# ax1.set_aspect(1.0/ax1.get_data_ratio(), adjustable='box')
# ax1.tick_params(axis='both', labelsize=20, width=1)

# change all spines
# for axis in ['top','bottom','left','right']:
#     ax1.spines[axis].set_linewidth(2)

# import matplotlib.ticker as ticker

# ax1.xaxis.set_major_locator(ticker.MultipleLocator(3))

# plt.savefig('population_transfer_vs_temperature', bbox_inches='tight')
# Out:
# Text(0, 0.5, '$\\tilde T_H$')
